# %% [markdown]
# # Diagnostic demonstration for E3SM model outputs
#
# In this notebook, we will create visualizations of:
# - trends
# - annual cycles

# %%
import co2_diag.dataset_operations as co2ops

# %%
fp = '/Users/kauf418/projects/e3sm_co2_transport_evaluation/2_ExperimentFolder/model_output/postprocessed/60yr/test_co2_hist_files_ne4pg2_initialvalue_scenario_60yr.CO2.nc'

# %%
e3sm_collection = co2ops.e3sm.Collection.run_recipe_for_timeseries(verbose='INFO',
                                                                   load_from_file=False,
                                                                   nc_file=fp)
# Out:
# Loading dataset from file..
# Preprocessing ---
# Preprocessing done.
# /Users/kauf418/opt/anaconda3/envs/co2diag_py3.8/lib/python3.8/site-packages/co2_diag/dataset_operations/time.py:23: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   dataset['time'] = dataset.indexes['time'].to_datetimeindex()
# Applying selected bounds..
# selection(s) queued, but not yet executed. Ready for .execute_all()
# selection(s) queued, but not yet executed. Ready for .execute_all()
# mean calculation queued for all, but not yet executed. Ready for .execute_all()
# done.
# recipe execution time (seconds): 0.7992172241210938
