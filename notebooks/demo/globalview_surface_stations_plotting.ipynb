# %% [markdown]
# # Diagnostics demonstration for NOAA Observation Package (Obspack)
#
# In this notebook, we will create visualizations of:
# - trends
# - annual cycles

# %% [markdown]
# ## Setup

# %%
from co2_diag.data_source.obspack.surface_stations import Collection as co2pack

# %% [markdown]
# ## Run the stored recipe

# %%
recipe_options={'ref_data': '/Users/kauf418/projects/e3sm_co2_transport_evaluation/2_ExperimentFolder/raw_data/noaa-obspack/obspack_co2_1_GLOBALVIEWplus_v6.0_2020-09-11/data/nc/',
          'station_code':'mlo',
          'start_yr': "1980",
          'end_yr': "2010"}
obspack_collection = co2pack.run_recipe_for_timeseries(options=recipe_options, verbose='INFO')
# Out:
# recipe execution time (seconds): 4.919393062591553

# %%
recipe_options={'ref_data': '/Users/kauf418/projects/e3sm_co2_transport_evaluation/2_ExperimentFolder/raw_data/noaa-obspack/obspack_co2_1_GLOBALVIEWplus_v6.0_2020-09-11/data/nc/',
          'station_code':'brw',
          'start_yr': "1970",
          'end_yr': "2010"}
obspack_collection = co2pack.run_recipe_for_annual_series(options=recipe_options, verbose='INFO')
# Out:
# Applying selected bounds..
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...
