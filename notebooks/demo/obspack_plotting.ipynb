# %% [markdown]
# # Diagnostics demonstration for NOAA Observation Package (Obspack)
#
# In this notebook, we will create visualizations of:
# - trends
# - annual cycles

# %% [markdown]
# ## Setup

# %%
import co2_diag.dataset_operations as co2ops

# %% [markdown]
# ## Run the stored recipe

# %%
datadir  = '/Users/kauf418/projects/e3sm_co2_transport_evaluation/2_ExperimentFolder/raw_data/noaa-obspack/obspack_co2_1_GLOBALVIEWplus_v6.0_2020-09-11/data/nc/'

# %%
param_kw={'stationshortname':'mlo',
          'start_yr': "1970",
          'end_yr': "2010"}
obspack_collection = co2ops.obspack.Collection.run_recipe_for_timeseries(datadir=datadir, param_kw=param_kw, verbose='INFO')
# Out:
# Loading data for 6 observing stations..
# recipe execution time (seconds): 4.744361877441406

# %%
param_kw={'stationshortname':'brw',
          'start_yr': "1970",
          'end_yr': "2010"}
obspack_collection = co2ops.obspack.Collection.run_recipe_for_annual_series(datadir=datadir, param_kw=param_kw, verbose='INFO')
# Out:
# Loading data for 6 observing stations..
# Applying selected bounds..
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...
